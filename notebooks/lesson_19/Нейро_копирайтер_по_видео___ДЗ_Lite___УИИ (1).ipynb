# %% [markdown]
# Найдите на ютубе интересную лекцию и запустите на ней нейро-копирайтера. Получите аудио-дорожку, на шаге транскрибации переведите текст на английский язык (для этого изучите документацию whisper - https://github.com/openai/whisper).
#
# Сделайте нейро консультанта на базе, который бы отвечал на русском языке, а методичку - на английском.

# %%
# !sudo apt-get install python3.12
# Out:
# "sudo" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.12
# Out:
# "python3.12" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.12 1
# Out:
# "sudo" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
# !sudo update-alternatives --config python3
# Out:
# "sudo" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
# !python3 --version
# Out:
# Python 3.11.9

# %%
# @title Устанавливаем whisper и yt-dlp
# Устанавливаем библиотеку для загрузки звука с видео. документация https://github.com/yt-dlp/yt-dlp?tab=readme-ov-file#readme
# !pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org -q yt-dlp -U

# !pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org git+https://github.com/openai/whisper.git
from IPython.display import clear_output
#clear_output()
# Out:
# C:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip_system_certs\wrapt_requests.py:71: UserWarning: Failed to patch SSL settings for unverified requests (unsupported version of urllib3?)
# This may lead to errors when urllib3 tries to modify verify_mode.
# Please report an issue at https://gitlab.com/alelec/pip-system-certs with your
# python version included in the description
#
#   warnings.warn(
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to c:\users\sasakinme\appdata\local\temp\pip-req-build-2da8x8k7
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: more-itertools in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper==20240930) (10.5.0)
# Requirement already satisfied: numba in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper==20240930) (0.60.0)
# Requirement already satisfied: numpy in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper==20240930) (1.26.3)
# Requirement already satisfied: tiktoken in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper==20240930) (0.7.0)
# Requirement already satisfied: torch in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper==20240930) (2.5.1)
# Requirement already satisfied: tqdm in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper==20240930) (4.66.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from numba->openai-whisper==20240930) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from tiktoken->openai-whisper==20240930) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from tiktoken->openai-whisper==20240930) (2.31.0)
# Requirement already satisfied: filelock in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper==20240930) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper==20240930) (4.12.2)
# Requirement already satisfied: networkx in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper==20240930) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper==20240930) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper==20240930) (2024.10.0)
# Requirement already satisfied: setuptools in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper==20240930) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper==20240930) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch->openai-whisper==20240930) (1.3.0)
# Requirement already satisfied: colorama in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from tqdm->openai-whisper==20240930) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->openai-whisper==20240930) (2.1.3)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git 'C:\Users\sasakinme\AppData\Local\Temp\pip-req-build-2da8x8k7'

# %%
# !pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org -q tiktoken==0.7.0 openai==1.41.1 langchain==0.2.14 langchain_community==0.2.12 langchain-openai==0.1.22 faiss-cpu==1.8.0 python-docx==1.1.0
from IPython.display import clear_output
#clear_output()

# %%
import whisper
import os
import gdown
import requests
import re
import time
from IPython.display import HTML, clear_output
import subprocess
from pathlib import Path
import json
import tiktoken
from docx import Document
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
import ipywidgets as widgets
from IPython.display import display
from tqdm.auto import tqdm
import getpass
import pickle
from urllib.request import urlopen
import openai
import subprocess
import codecs
from langchain.chains import ConversationChain         # Импортируем класс для создания цепочек диалогов
from langchain.memory import ConversationBufferMemory  # Импортируем класс для управления памятью диалогов
from langchain.text_splitter import MarkdownHeaderTextSplitter, RecursiveCharacterTextSplitter
import os
import glob
import shutil
import urllib

# %%
# !pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org gdown ipywidgets
# Out:
# Requirement already satisfied: gdown in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (5.2.0)
# Requirement already satisfied: ipywidgets in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (8.1.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from gdown) (4.66.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: colorama in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
import yt_dlp

# Ссылка на видео YouTube для скачивания
URLS = ['https://www.youtube.com/watch?v=rV3y-hcyEcM']  # указываем ссылку для получения аудио-дорожки из видео

# Придумаем короткое имя для сохраняемого аудио файла на английском языке.
name = 'My_Audio_2'
file_name = f"download_{name}.m4a"

cookie_file_path = r"C:\Users\sasakinme\IdeaProjects\other\chatgpt-professional\notebooks\lesson_19\cookies.txt"

# Значения для получения лучшего качества звука из документации.
ydl_opts = {
    'format': 'm4a/bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'm4a',
    }],
    'outtmpl': file_name,
    'nocheckcertificate': True,
    'cookiefile': cookie_file_path
}

# Проверка наличия файла cookie
import os
if not os.path.exists(cookie_file_path):
    print(f"Файл {cookie_file_path} не найден.")
else:
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download(URLS)
        if error_code == 0:
            print('Загрузка файла прошла успешно!')
        else:
            print(f'Код ошибки: {error_code}')

    print(f"\nАудиофайл загружен, имя файла: {file_name}")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rV3y-hcyEcM
# [youtube] rV3y-hcyEcM: Downloading webpage
# [youtube] rV3y-hcyEcM: Downloading tv client config
# [youtube] rV3y-hcyEcM: Downloading player 69f581a5
# [youtube] rV3y-hcyEcM: Downloading tv player API JSON
# [info] rV3y-hcyEcM: Downloading 1 format(s): 140
# [download] download_My_Audio_2.m4a has already been downloaded
# [download] 100% of   92.07MiB
# [ExtractAudio] Not converting audio download_My_Audio_2.m4a; file is already in target format m4a
# Загрузка файла прошла успешно!
#
# Аудиофайл загружен, имя файла: download_My_Audio_2.m4a

# %%
# !pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org  faster_whisper
# Out:
# Collecting faster_whisper
#   Downloading faster_whisper-1.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting ctranslate2<5,>=4.0 (from faster_whisper)
#   Downloading ctranslate2-4.5.0-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.13 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from faster_whisper) (0.27.0)
# Requirement already satisfied: tokenizers<1,>=0.13 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from faster_whisper) (0.21.0)
# Requirement already satisfied: onnxruntime<2,>=1.14 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from faster_whisper) (1.20.1)
# Collecting av>=11 (from faster_whisper)
#   Downloading av-14.2.0-cp312-cp312-win_amd64.whl.metadata (4.8 kB)
# Requirement already satisfied: tqdm in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from faster_whisper) (4.66.1)
# Requirement already satisfied: setuptools in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ctranslate2<5,>=4.0->faster_whisper) (75.8.0)
# Requirement already satisfied: numpy in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ctranslate2<5,>=4.0->faster_whisper) (1.26.3)
# Requirement already satisfied: pyyaml<7,>=5.3 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ctranslate2<5,>=4.0->faster_whisper) (6.0.1)
# Requirement already satisfied: filelock in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.13->faster_whisper) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.13->faster_whisper) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.13->faster_whisper) (23.2)
# Requirement already satisfied: requests in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.13->faster_whisper) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.13->faster_whisper) (4.12.2)
# Requirement already satisfied: coloredlogs in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime<2,>=1.14->faster_whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime<2,>=1.14->faster_whisper) (24.12.23)
# Requirement already satisfied: protobuf in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime<2,>=1.14->faster_whisper) (4.25.5)
# Requirement already satisfied: sympy in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime<2,>=1.14->faster_whisper) (1.13.1)
# Requirement already satisfied: colorama in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from tqdm->faster_whisper) (0.4.6)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from coloredlogs->onnxruntime<2,>=1.14->faster_whisper) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from sympy->onnxruntime<2,>=1.14->faster_whisper) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime<2,>=1.14->faster_whisper) (3.5.4)
# Downloading faster_whisper-1.1.1-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------- ----------- 0.8/1.1 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 6.8 MB/s eta 0:00:00
# Downloading av-14.2.0-cp312-cp312-win_amd64.whl (30.9 MB)
#    ---------------------------------------- 0.0/30.9 MB ? eta -:--:--
#    ------- -------------------------------- 6.0/30.9 MB 33.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 13.1/30.9 MB 31.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 22.8/30.9 MB 37.0 MB/s eta 0:00:01
#    ---------------------------------------  30.7/30.9 MB 37.4 MB/s eta 0:00:01
#    ---------------------------------------- 30.9/30.9 MB 35.0 MB/s eta 0:00:00
# Downloading ctranslate2-4.5.0-cp312-cp312-win_amd64.whl (19.5 MB)
#    ---------------------------------------- 0.0/19.5 MB ? eta -:--:--
#    -------------------- ------------------- 10.0/19.5 MB 47.8 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.5 MB 47.1 MB/s eta 0:00:01
#    ---------------------------------------- 19.5/19.5 MB 42.4 MB/s eta 0:00:00
# Installing collected packages: ctranslate2, av, faster_whisper
# Successfully installed av-14.2.0 ctranslate2-4.5.0 faster_whisper-1.1.1

# %%
# !pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org ipython
# Out:
# Requirement already satisfied: ipython in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (9.0.2)
# Requirement already satisfied: colorama in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (2.18.0)
# Requirement already satisfied: stack_data in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython) (0.2.3)

# %%
# !pip install --trusted-host pypi.org --upgrade urllib3
# Out:
# Requirement already satisfied: urllib3 in c:\users\sasakinme\appdata\local\programs\python\python312\lib\site-packages (2.3.0)
# C:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip_system_certs\wrapt_requests.py:71: UserWarning: Failed to patch SSL settings for unverified requests (unsupported version of urllib3?)
# This may lead to errors when urllib3 tries to modify verify_mode.
# Please report an issue at https://gitlab.com/alelec/pip-system-certs with your
# python version included in the description
#
#   warnings.warn(

# %%
from faster_whisper import WhisperModel
import whisper
import os
import torch
from pydub import AudioSegment
from transformers import WhisperProcessor, WhisperForConditionalGeneration

def transcribe_audio_whisper_chunked(audio_path, file_title, save_folder_path, max_duration=5 * 60 * 1000):  # 5 минут
    """
    Функция для транскрибации аудиофайла на части, чтобы соответствовать ограничениям размера API.
    """

    # Создание папки для сохранения результатов, если она ещё не существует
    os.makedirs(save_folder_path, exist_ok=True)

    # Загрузка аудиофайла
    audio = AudioSegment.from_file(audio_path)

    # Создание временной папки для хранения аудио чанков (фрагментов)
    temp_dir = os.path.join(save_folder_path, "temp_audio_chunks")
    os.makedirs(temp_dir, exist_ok=True)

    # Инициализация переменных для обработки аудио чанков
    current_start_time = 0  # Текущее время начала чанка
    chunk_index = 1         # Индекс текущего чанка
    transcriptions = []     # Список для хранения всех транскрибаций

    # Загрузка модели и процессора
    processor = WhisperProcessor.from_pretrained("openai/whisper-large-v3")
    model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-large-v3")
    #model = whisper.load_model("large")  # Вы можете выбрать 'tiny', 'base', 'small', 'medium', 'large'

    # Обработка аудиофайла чанками
    while current_start_time < len(audio):
        # Выделение чанка из аудиофайла
        chunk = audio[current_start_time:current_start_time + max_duration]
        # Формирование имени и пути файла чанка
        chunk_name = f"chunk_{chunk_index}.wav"
        chunk_path = os.path.join(temp_dir, chunk_name)
        # Экспорт чанка в формате wav
        chunk.export(chunk_path, format="wav")

        # Проверка размера файла чанка на соответствие лимиту API
        if os.path.getsize(chunk_path) > 26214400:  # 25 MB
            print(f"Chunk {chunk_index} exceeds the maximum size limit for the API. Trying a smaller duration...")
            max_duration = int(max_duration * 0.9)  # Уменьшение длительности чанка на 10%
            os.remove(chunk_path)  # Удаление чанка, превышающего лимит
            continue

        # Загрузка аудио чанка
        chunk_audio = AudioSegment.from_file(chunk_path)
        chunk_audio = chunk_audio.set_frame_rate(16000).set_channels(1)
        audio_array = torch.tensor(chunk_audio.get_array_of_samples(), dtype=torch.float32).unsqueeze(0)

        # Предобработка аудиофайла
        inputs = processor(audio_array.numpy(), sampling_rate=16000, return_tensors="pt")
        #inputs['attention_mask'] = torch.ones_like(inputs['input_features'])

        # Транскрибирование
        #generated_ids = model.generate(inputs["input_features"], max_length=500)
        #transcription = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

        # Транскрибирование с переводом на английский
        # Если attention_mask не создается автоматически, создайте его вручную
        if 'attention_mask' not in inputs:
            inputs['attention_mask'] = torch.ones_like(inputs['input_features'])

        # Транскрибирование с переводом на английский
        generated_ids = model.generate(inputs["input_features"], max_length=500, language='en')
        transcription = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

        # Добавление результата транскрибации в список транскрипций
        transcriptions.append(transcription)
        print(transcription)

        # Удаление обработанного файла чанка
        os.remove(chunk_path)
        # Переход к следующему чанку
        current_start_time += max_duration
        chunk_index += 1

    # Удаление временной папки с чанками
    os.rmdir(temp_dir)

    # Сохранение всех транскрипций в один текстовый файл
    result_path = os.path.join(save_folder_path, f"{file_title}.txt")
    with open(result_path, "w") as txt_file:
        txt_file.write("\n".join(transcriptions))

    print(f"Transcription saved to {result_path}")

# %%
# Пример использования
audio_path = "download_My_Audio_2.m4a"
file_title = "text"
save_folder_path = "transcribe/"

transcribe_audio_whisper_chunked(audio_path, file_title, save_folder_path)
# Out:
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\sasakinme\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'huggingface.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Chunk 1 exceeds the maximum size limit for the API. Trying a smaller duration...
# Chunk 1 exceeds the maximum size limit for the API. Trying a smaller duration...
# Chunk 1 exceeds the maximum size limit for the API. Trying a smaller duration...
# Chunk 1 exceeds the maximum size limit for the API. Trying a smaller duration...
# Chunk 1 exceeds the maximum size limit for the API. Trying a smaller duration...
# Chunk 1 exceeds the maximum size limit for the API. Trying a smaller duration...
# Chunk 1 exceeds the maximum size limit for the API. Trying a smaller duration...
#  As you probably guessed, my name is Yuri Litvinov and I will be taking a course on the programming of software this semester. Today we have an annual lecture, about what the course will be in general, and I will tell you a little about what exactly is architecture and why to study it.
#  of some very beginning, that is, the object of the virtual design, what is such a class object, that you probably already know, but it would probably be nice to look at it again, in the list of his already, I hope, having experience in programming. There will be a lot about the architect's tools, that is, the language of visual modeling, design patterns, this is also, in fact, in general, things that are often told on the basic course of programming,
#  This course is actually read in the St. Petersburg University, it is already in the School of Economics, the course is read. The practice shows that it flies into one ear and another one flies out. Because there are many knowledge, without their application, they quickly merge into one bunch. We will have tasks to design some kind of system according to the specificity, there will be several. The first example of such a task is a house, which is for today.
#  There was not a huge amount of given tasks, which did not work out. There will be a double. Moreover, the evaluation system is arranged in such a way that the pre-probe double points are halved, that is, tasks can still be passed and need to be passed, but for less points. Therefore, we must try to make it happen.
#  and put it there. Put each task in a separate branch, do the main pull request and send a link to the pull request as a solution. Ok? Yes, thank you. And what is the short one on the fourth? Well, I didn't count.
#  that is, you do not need to inspect the special network, you will have all the material, but they are quite beautiful, I agree with you, yes. Any more questions? What is your preferred recipe? What do you like best?
#  At first, homebases will imply one code base. If your selected technology allows it, you can use it without any problems. For example, on Javi and Kotany you can write one project without any problems, or on C sharp and F sharp. Then, perhaps, there will be tasks that allow you to write in any language at all.
#  you are not the first to raise your hands who does not know how to set up SBI, CI somewhere on GitHub Actions, Flare or somewhere else. That is, I see that there are quite a lot. On the one hand, less than half, so you can probably share the teams somehow so that some of you knew, and some did not know, you could learn by hand.
#  In home programming, you don't need to try to make it as simple as possible. Because most likely everything that you will be asked will be done with a two-stroke pipe. Without any architecture, general architecture and other ground. Don't do it because of the cost of architecture. Try to use knowledge of science, or patterns, architectural styles,
#  Unfortunately, you can't give a task to develop an average size information system of 1000 code lines, so 150. Just because you can't fix it. But it would be great. By the way, it was written in the prerequisite that it would be cool if you already had some programming, then you wrote as many large systems as possible. As part of, for example, human practice. Well, if not, then it's not scary.
#  Any questions? Then let's finally move on to the content part and start with what is architecture in general and what it is for. There is a famous picture from the not least famous book by Brooks, The Mythic Man-Month. By the way, raise your hands who read it.
#  of large and external programs, operating systems, equipment, utilities, libraries, etc. Therefore, the program must have the means of integration, provide some interfaces that other programs can use, the site needs some interfaces, and have integration tests that prove that all this really works.
#  4 people. This is good. Because in my studies I did not write such systems. Even 5. More than 5000 barcodes. I mean, just one system. Not all of them are at home. Those who wrote systems with less than 5000 barcodes, with architectural tasks,
#  it's just pointless to write. They will fall apart under their own weight. And, in fact, the problem of this course is that most of you probably think that this is not necessary for anyone, because we will write small systems, this architecture is not needed. This is true. Again, if you are going to work as a judge all your life and write one-page websites or write mobile games or even write a lot of different good and smart data science in a carton,
#  Wikipedia defines architecture as a complex and complex solution to the organization of the program system. Cool, what is the most important solution? What is the organization of the program system? What solutions should be included in architecture? What are not needed? And so on and so forth. Indeed, architecture is formally not defined in any way. And in this course we will take the point of view of production,
#  to restore the architecture according to the already written code. This is a big job, and by the way, at the end of the couple I will tell you about it. And in general, the architecture is not made of stone, it does not descend. In some cases, it is a structure from the architect who sits in his chair, the architect is in architecture or something. It will survive. In addition, the architecture consists of different points of view on the system,
#  It gives a solution in the sense that we have a command line interface, it has a parser, it has a rom parser, it has an interpreter, it interprets the interpreter from the parser. I say great, but the level of utilization is such that we can never finish it. On the other hand, code is also architecture. Note that code contains all the information about the system. Well, almost everything, in fact. It contains an explanation of why it is so.
#  Well, in fact, if you had a partner, you would know that when you sign a contract for development, you actually play a fun game, guessing its value. Because if you take on a price too high, the customer will simply go to the competitor and you will not get money.
#  In addition, architecture is a good way to save time in development, because if you can accurately bring out the general functionality of some common blocks, you can use standard libraries instead of these blocks. Keep in mind that everything that you can think about and that you need, is probably already implemented at home or with GitHub.
#  Architects are engaged in the process of learning, as probably hard to guess. Architect is a separate profession. In fact, an architect usually does not become in the process of learning, but becomes a little by work. Architect is a visible person or a group of people, even in large projects, who are responsible for development and description of the system, first of all.
#  its key labor functions, which are then revealed in labor actions, and so on. You can see it in the standard assembly. There is a lot of good things written there. Well, by the way, there is really a lot of good things written there. That is, there is really a lot of things that the architect should know about. Well, and here, in fact, it is written here the same as in the previous slide. That is, the architect is engaged in analyzing the requirements from the point of view of architecture.
#  it is desirable to have a master's degree to try to become an architect. Architects are also the leadership positions. By the way, it is important to understand that architects in real life grow from developers, but these are completely different people. They must have a lot of technical skills, but the developer must understand
#  It is terrible to sit and talk with no one, it's great, but the architect has another job. Also, the architect must be programmed in some way. It turns out to be, because architects grow up from developers, and rarely take someone on the profession of an architect at once.
#  he has a gap between what he has invented and what he can actually easily and quickly implement with the available tools. So, you don't have to do that either. Questions? Thoughts? No questions, thoughts.
#  Probably, at first it was possible to get away without architecture, because programming was in machine codes or in the language of assembler. There was no architecture, there were a maximum of 100 teams, because the operator was not used anymore. There you could figure it out anyway. But then big terrible systems were created. Cici, Plus Plus, Pascal, I don't know, Vinda. Vinda, okay, Vinda appeared a little later, but the first code that concerned modern computer systems
#  to solve such a task. They have customers who want specific functions of the cellographs. Accordingly, for these customers, custom fuses are previously made. While the cellographs were simple, everything was easy and pleasant, but the cellographs became difficult. And now rewriting the same firmware, but with slightly different functions, became too cumbersome. So, a decision was made,
#  to make order in such a case and from where. Naturally, it would be to implement layered styles, which, in principle, then was already quite known, because there were models of OSI, TCP, IP even, at that time there was already, well, and there were a lot of very layered architectures, which here recommended themselves well.
#  to function, maybe something useful more or less. This skill, in principle, was liked by the experts in the field of mathematics, because it is an example of corresponding to their idea of how the oscillograph works. We take, capture the signal, perform transformations, perform the calculations of graphs,
#  or a process, a separate stream, or just a sequence of emerging filters, and so on. This is their business. The main thing is that they can take data from the channel and issue it to the next channel. And we can manage these filters using the transmission of the current of the action. Also with strict topological restrictions. That is, we can look at the picture and see how the system works, and it is still warm.
#  Perhaps, he had a friend, and if he didn't, then maybe just from somewhere. Well, these are all rather such technical metrics. They can be good for a bad architecture without problems. And they can be bad for a good architecture. Rarely, but it happens. In fact, architecture is a humanitarian science. Again, such a rather terrible confession for the educational program of the
#  network protocols, operating systems, and many more. There are object-oriented architectures, it can be used for anything. There are channels and filters, which are also used not only for oscillographers, but also for different mathematical calculations.
#  Again, look, we have designed the same system here. This is its static structure from the object. This is also a static structure. This is how the system looks during compilation. We have components that are responsible for encryption, components that are responsible for visualization, components that are responsible for searching for interfaces. This is already a dynamic state of the system, because in fact, inside the conveyor,
#  If briefly, then there is a context that fixes the system environment, that is, does not reveal the system in any way, but just shows the system users, data that the system consumes and gives out, and so on. The composition describes the large part of the system, how they are interconnected, and what each part of the system does.
#  where the key algorithms of the system are described. If they exist. Most of the systems, unfortunately, probably, unfortunately, for the fans of computer programming, most of the systems do not contain any new algorithms. Resources describe external resources,
#  The system should be fundamentally complex to be useful in programming, but not exactly like that. However, complexity can be decomposed, and complexity can be controlled. Modeling is also a way to control complexity. Modeling allows us to choose from the general complexity of the system some key aspects that are observable and with which we can somehow fight.
#  And there are cases of use of this functionality, which the system provides to its actors. The diagram will be more detailed later, but for now the general idea is this. Each actor is approximately one working place, roughly speaking, that is, it is a user interface, which has some functionality. In any case, the use corresponds to some set of scenarios,
#  then your system will probably be completely different from if you were told that it costs 1 billion dollars and 10 years to develop. You just won't have time to deal with it at all. Functional requirements suddenly have the least influence on architecture. Three functional requirements are key, so-called architectural drivers. Requirements that will have the maximum influence.
#  When designing architecture, I think it is clear how this diagram of components is used. This is probably the most useful diagram when designing, because it does not change with each check, with each refactoring of our project. When designing, it is necessary to take into account, and this is important, in fact, we will still try to do it in practice, that there are general questions for all systems,
#  Erosion is critically dangerous, because the architectural documentation becomes openly incorrect. A new person comes to the team, and they tell him, well, read the documentation, and then you will sign. He has read the documentation, he cannot sign, because it is completely different in the code. Or he sends a bug, relying on his vision and the architectural system, it turns out that his vision has already become worse.
#  as it is described in the book in the architectural documentation of Hadoop and in the book for the architecture of open source applications I will show it later, when I will tell more about the example architecture it looks like this there are data nodes combined in a stack in which live data blocks and data nodes are engaged in the same processing
#  Here is another representation in the form of a hierarchical diagram of who calls whom. It is completely unreadable, but it was actually thought out, because the main point is that this is the kind of system obtained by the course, this is the system described in the documentation. This is the descriptive architecture. It is really like this, because
#  the code and Hadoop do not correspond to the logic component. That is, there was about 50 components in the system during the investigation. You can look at the prospect, I wrote a little bit about it. And about 40 of them do not correspond to the folders in which they are stored in the system files.
# Transcription saved to transcribe/text.txt

# %%
# @title Установка и импорты
import shutil
from langchain.docstore.document import Document
from langchain_openai import OpenAI
from IPython.display import display, HTML

#from google.colab import drive
#drive.mount('/content/drive', force_remount=True)

# %%
#@title Разделяем текст на логические блоки с выделением названия раздела:
system = '\u0412\u044B \u0433\u0435\u043D\u0438\u0439 \u0442\u0435\u043A\u0441\u0442\u0430, \u043A\u043E\u043F\u0438\u0440\u0430\u0439\u0442\u0438\u043D\u0433\u0430, \u043F\u0438\u0441\u0430\u0442\u0435\u043B\u044C\u0441\u0442\u0432\u0430. \u0412\u0430\u0448\u0430 \u0437\u0430\u0434\u0430\u0447\u0430 \u0440\u0430\u0441\u043F\u043E\u0437\u043D\u0430\u0442\u044C \u0440\u0430\u0437\u0434\u0435\u043B\u044B \u0432 \u0442\u0435\u043A\u0441\u0442\u0435 \u0438 \u0440\u0430\u0437\u0431\u0438\u0442\u044C \u0435\u0433\u043E \u043D\u0430 \u044D\u0442\u0438 \u0440\u0430\u0437\u0434\u0435\u043B\u044B \u0441\u043E\u0445\u0440\u0430\u043D\u044F\u044F \u0432\u0435\u0441\u044C \u0442\u0435\u043A\u0441\u0442 \u043D\u0430 100%' #@param {type:"string"}
user = '\u041F\u043E\u0436\u0430\u043B\u0443\u0439\u0441\u0442\u0430, \u0434\u0430\u0432\u0430\u0439\u0442\u0435 \u043F\u043E\u0434\u0443\u043C\u0430\u0435\u043C \u0448\u0430\u0433 \u0437\u0430 \u0448\u0430\u0433\u043E\u043C: \u041F\u043E\u0434\u0443\u043C\u0430\u0439\u0442\u0435, \u043A\u0430\u043A\u0438\u0435 \u0440\u0430\u0437\u0434\u0435\u043B\u044B \u0432 \u0442\u0435\u043A\u0441\u0442\u0435 \u0432\u044B \u043C\u043E\u0436\u0435\u0442\u0435 \u0440\u0430\u0441\u043F\u043E\u0437\u043D\u0430\u0442\u044C \u0438 \u043A\u0430\u043A\u043E\u0435 \u043D\u0430\u0437\u0432\u0430\u043D\u0438\u0435 \u043F\u043E \u0441\u043C\u044B\u0441\u043B\u0443 \u043C\u043E\u0436\u043D\u043E \u0434\u0430\u0442\u044C \u043A\u0430\u0436\u0434\u043E\u043C\u0443 \u0440\u0430\u0437\u0434\u0435\u043B\u0443. \u0414\u0430\u043B\u0435\u0435 \u043D\u0430\u043F\u0438\u0448\u0438\u0442\u0435 \u043E\u0442\u0432\u0435\u0442 \u043F\u043E \u0432\u0441\u0435\u043C\u0443 \u043F\u0440\u0435\u0434\u044B\u0434\u0443\u0449\u0435\u043C\u0443 \u043E\u0442\u0432\u0435\u0442\u0443 \u0432 \u043F\u043E\u0440\u044F\u0434\u043A\u0435: ## \u041D\u0430\u0437\u0432\u0430\u043D\u0438\u0435 \u0440\u0430\u0437\u0434\u0435\u043B\u0430, \u043F\u043E\u0441\u043B\u0435 \u0447\u0435\u0433\u043E \u0432\u0435\u0441\u044C \u0442\u0435\u043A\u0441\u0442, \u043E\u0442\u043D\u043E\u0441\u044F\u0449\u0438\u0439\u0441\u044F \u043A \u044D\u0442\u043E\u043C\u0443 \u0440\u0430\u0437\u0434\u0435\u043B\u0443. \u0422\u0435\u043A\u0441\u0442:' #@param {type:"string"}

temperature = 0 #@param {type: "slider", min: 0, max: 1, step:0.1}
chunk_size = 7000 #@param {type: "slider", min: 1000, max: 7000, step:500}
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
from openai import OpenAI  
BASE_URL = "https://openrouter.ai/api/v1"
API_KEY = os.environ.get("OPENAI_API_KEY")
MODEL = "deepseek/deepseek-r1-distill-qwen-32b:free"
client = OpenAI(api_key=API_KEY, base_url=BASE_URL)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
# Удаление всех обработчиков событий 'pre_run_cell'
ip = get_ipython()
if 'pre_run_cell' in ip.events.callbacks:
    for handler in ip.events.callbacks['pre_run_cell'].copy():
        ip.events.unregister('pre_run_cell', handler)
print(ip.events.callbacks)
# Out:
# {'pre_execute': [<bound method InteractiveShell._clear_warning_registry of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000023192EC7EF0>>], 'pre_run_cell': [], 'post_execute': [], 'post_run_cell': [], 'shell_initialized': []}

# %%
# @title Функции
# Функция настройки стиля для переноса текста в выводе ячеек
# для изменения стиля отображения текста, так чтобы предотвратить переполнение текста за границы ячейки вывода и обеспечить его перенос.

from IPython import get_ipython
def set_text_wrap_css(tmp):
    css = '''
    <style>
    pre {
        white-space: pre-wrap;
    }
    </style>
    '''
    display(HTML(css)) 
    
get_ipython().events.register('pre_run_cell', set_text_wrap_css)

# %%
# Функция подсчета количества токенов
def num_tokens_from_messages(messages, model=MODEL):
    try:
        encoding = tiktoken.encoding_for_model(model)
    except KeyError:
        encoding = tiktoken.get_encoding('cl100k_base')

    if model in ['deepseek/deepseek-r1-distill-qwen-32b:free', 'qwen/qwen2.5-vl-72b-instruct:free', 'gpt-4o-latest']:
        num_tokens = 0

        for message in messages:
            num_tokens += 4

            for key, value in message.items():
                num_tokens += len(encoding.encode(value))

                if key == 'name':
                    num_tokens -= 1

        num_tokens += 2
        return num_tokens

    else:
        raise NotImplementedError(f'''num_tokens_from_messages() is not presently implemented for model {model}.''')


# Функция дробления текста на чанки
def split_text(txt_file, chunk_size=chunk_size):
    source_chunks = []
    splitter = RecursiveCharacterTextSplitter(separators=['\n', '\n\n', '. '], chunk_size=chunk_size, chunk_overlap=0)

    for chunk in splitter.split_text(txt_file):
        source_chunks.append(Document(page_content=chunk, metadata={"meta":"data"}))

    print(f'\n\nТекст разбит на {len(source_chunks)} чанков.')

    return source_chunks


# Функция получения ответа от модели
def answer_index(system, user, chunk, temp=temperature, model=MODEL):

    messages = [
        {'role': 'system', 'content': system},
        {'role': 'user', 'content': user + f'{chunk}'}
    ]

    completion = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temp
    )

    # Вывод количества токенов отключен
    # print(f'\n====================\n\n{num_tokens_from_messages(messages)} токенов будет использовано на чанк\n\n')
    answer = completion.choices[0].message.content

    return answer


def process_one_file(file_path, system, user):
    with open(file_path, 'r') as txt_file:
        text = txt_file.read()
    source_chunks = split_text(text)
    processed_text = ''
    unprocessed_text = ''

    for chunk in source_chunks:
        attempt = 0

        while attempt < 3:
            try:
                answer = answer_index(system, user, chunk.page_content)
                break  # Успешно получили ответ, выходим из цикла попыток

            except Exception as e:
                attempt += 1  # Увеличиваем счетчик попыток
                print(f'\n\nПопытка {attempt} не удалась из-за ошибки: {str(e)}')
                time.sleep(10)  # Ожидаем перед следующей попыткой
                if attempt == 3:
                    answer = ''
                    print(f'\n\nОбработка элемента {chunk} не удалась после 3 попыток')
                    unprocessed_text += f'{chunk}\n\n'

        processed_text += f'{answer}\n\n'  # Добавляем ответ в результат
        print(f'{answer}')  # Выводим ответ

    return processed_text, unprocessed_text
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
# @title Запуск
system_en = 'You are a text generator, copyrighting, and writing assistant. Your task is to parse sections in the text and split it into these sections while preserving all the text at 100%.' #@param {type:"string"}
user_en = 'Please, let\'s think step by step: First, consider which sections in the text you can parse and what title can be given to each section based on its meaning. Then write the response to the previous prompt in the following order: ## Title of the section, followed by the entire text, relating to this section. Text:' #@param {type:"string"}
MODEL = "qwen/qwen2.5-vl-72b-instruct:free"
file_path = 'transcribe/text.txt'
#file_path = '/content/transcriptions/Графы_Алгоритмы_и_Структуры_Данных_на_Python.txt'
# Вызываем функцию обработки для этого файла
processed_text, unprocessed_text = process_one_file(file_path, system_en, user_en)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# Текст разбит на 3 чанков.
# Here is the text split into sections based on the thought process:
#
# ---
#
# ## Introduction
# As you probably guessed, my name is Yuri Litvinov and I will be taking a course on the programming of software this semester. Today we have an annual lecture about what the course will be in general, and I will tell you a little about what exactly is architecture and why to study it.
#
# ---
#
# ## Course Structure and Tasks
# The course is actually read in the St. Petersburg University, it is already in the School of Economics, the course is read. The practice shows that it flies into one ear and another one flies out. Because there are many knowledge, without their application, they quickly merge into one bunch. We will have tasks to design some kind of system according to the specificity, there will be several. The first example of such a task is a house, which is for today.
#
# ---
#
# ## Evaluation and Submission
# There was not a huge amount of given tasks, which did not work out. There will be a double. Moreover, the evaluation system is arranged in such a way that the pre-probe double points are halved, that is, tasks can still be passed and need to be passed, but for less points. Therefore, we must try to make it happen.
#
# ---
#
# ## Technology and Tools
# You are not the first to raise your hands who does not know how to set up SBI, CI somewhere on GitHub Actions, Flare or somewhere else. That is, I see that there are quite a lot. On the one hand, less than half, so you can probably share the teams somehow so that some of you knew, and some did not know, you could learn by hand.
#
# ---
#
# ## Addressing Concerns
# In home programming, you don't need to try to make it as simple as possible. Because most likely everything that you will be asked will be done with a two-stroke pipe. Without any architecture, general architecture and other ground. Don't do it because of the cost of architecture. Try to use knowledge of science, or patterns, architectural styles.
#
# ---
#
# ## Importance of Architecture
# Unfortunately, you can't give a task to develop an average size information system of 1000 code lines, so 150. Just because you can't fix it. But it would be great. By the way, it was written in the prerequisite that it would be cool if you already had some programming, then you wrote as many large systems as possible. As part of, for example, human practice. Well, if not, then it's not scary.
#
# ---
#
# ## Definition and Role of Architecture
# Architecture is formally not defined in any way. And in this course, we will take the point of view of production, to restore the architecture according to the already written code. This is a big job, and by the way, at the end of the couple, I will tell you about it. And in general, the architecture is not made of stone, it does not descend. In some cases, it is a structure from the architect who sits in his chair, the architect is in architecture or something. It will survive. In addition, the architecture consists of different points of view on the system.
#
# ---
#
# ## Practical Aspects of Architecture
# It gives a solution in the sense that we have a command line interface, it has a parser, it has a rom parser, it has an interpreter, it interprets the interpreter from the parser. I say great, but the level of utilization is such that we can never finish it. On the other hand, code is also architecture. Note that code contains all the information about the system. Well, almost everything, in fact. It contains an explanation of why it is so.
#
# ---
#
# ## Business Implications of Architecture
# Well, in fact, if you had a partner, you would know that when you sign a contract for development, you actually play a fun game, guessing its value. Because if you take on a price too high, the customer will simply go to the competitor and you will not get money.
#
# In addition, architecture is a good way to save time in development, because if you can accurately bring out the general functionality of some common blocks, you can use standard libraries instead of these blocks. Keep in mind that everything that you can think about and that you need, is probably already implemented at home or with GitHub.
#
# Architects are engaged in the process of learning, as probably hard to guess. Architect is a separate profession. In fact, an architect usually does not become in the process of learning, but becomes a little by work. Architect is a visible person or a group of people, even in large projects, who are responsible for development and description of the system, first of all.
#
# ---
#
# Each section captures a distinct part of the lecture, ensuring all original text is preserved.
# Here is the text split into sections with appropriate titles:
#
# ---
#
# ### 1. The Role and Background of Architects
#
# The text discusses the role of architects in analyzing requirements from an architectural perspective. It highlights the desirability of a master's degree for architects and notes that architects often come from a developer background, which is different from developers. This section emphasizes the importance of technical skills and the leadership roles architects often hold.
#
# ---
#
# ### 2. The Necessity of Architecture in Modern Systems
#
# This section explains why architecture became essential as systems grew more complex. It contrasts early programming without architecture to the need for layered styles and models like OSI and TCP/IP. The text illustrates how architecture addresses the challenges of complex systems, making it a crucial element in modern software development.
#
# ---
#
# ### 3. System Architecture Components
#
# The text details the components of system architecture, including static and dynamic states, and specific responsibilities like encryption and visualization. It also covers context and composition, which are integral parts of system design, providing a comprehensive view of how different components interact within a system.
#
# ---
#
# ### 4. Modeling and Complexity Management
#
# This section focuses on methods to manage complexity in architecture, such as modeling. It explains how modeling helps isolate key aspects of a system and mentions the use of scenarios and use cases to define functionality. The text underscores the role of modeling in controlling complexity and ensuring system usability.
#
# ---
#
# ### 5. The Impact of Requirements and Challenges in Maintaining Architecture
#
# The final section discusses the importance of functional requirements as architectural drivers and the risks of architectural erosion when documentation becomes outdated. It highlights the challenges in keeping documentation accurate and relevant, emphasizing the need for continuous updates and reviews to maintain a coherent architecture.
#
# ---
#
# Each section is titled to reflect its content, ensuring a logical flow and comprehensive coverage of the topics discussed.
# ## Description of Hadoop Architecture
# As it is described in the book in the architectural documentation of Hadoop and in the book for the architecture of open source applications, I will show it later, when I will tell more about the example architecture. It looks like this: there are data nodes combined in a stack in which live data blocks and data nodes are engaged in the same processing.
#
# ## Hierarchical Diagram Representation
# Here is another representation in the form of a hierarchical diagram of who calls whom. It is completely unreadable, but it was actually thought out, because the main point is that this is the kind of system obtained by the course, this is the system described in the documentation. It is the descriptive architecture. It is really like this, because the code and Hadoop do not correspond to the logic component. That is, there was about 50 components in the system during the investigation. You can look at the prospect, I wrote a little bit about it. And about 40 of them do not correspond to the folders in which they are stored in the system files.

# %%
system_ru = """Вы являетесь консультантом по проектированию программного обеспечения. Ваша задача — отвечать на вопросы, связанные с лекцией, опираясь исключительно на предоставленный документ. Убедитесь, что ваши ответы:

Основываются только на информации из документа. В ответе не упоминай документ.
Четкие и понятные, с акцентом на основные идеи и темы лекции.

Пожалуйста, избегайте использования информации, не содержащейся в документе, и старайтесь давать исчерпывающие ответы на вопросы слушателей."""
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
source_chunks=[]
splitter = RecursiveCharacterTextSplitter("---")       # заполните нужными значениями, проведите эксперименты
for chunk in splitter.split_text(processed_text):
    source_chunks.append(Document(page_content=chunk, metadata={}))
print("Общее количество чанков: ", len(source_chunks))
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# Общее количество чанков:  3

# %%
from sentence_transformers import SentenceTransformer
#import re

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Функция для создания эмбеддингов из массива документов
def create_embeddings(documents):
    page_contents = [doc.page_content for doc in documents]
    return model.encode(page_contents)

# Создание эмбеддингов
embeddings = create_embeddings(source_chunks)

# Создадим индексную базу из разделенных фрагментов текста
import numpy as np
import faiss
# Преобразование эмбеддингов в массив numpy
embeddings = np.array(embeddings).astype('float32')

# Создание индекса FAISS
dimension = embeddings.shape[1]  # Размерность векторов
db = faiss.IndexFlatL2(dimension)  # Использование L2 метрики
# Добавление векторов в индекс
db.add(embeddings)

clear_output()

# %%
# Функция, которая позволяет выводить ответ модели в удобочитаемом виде
def insert_newlines(text: str, max_len: int = 170) -> str:
    words = text.split()
    lines = []
    current_line = ""
    for word in words:
        if len(current_line + " " + word) > max_len:
            lines.append(current_line)
            current_line = ""
        current_line += " " + word
    lines.append(current_line)
    return " ".join(lines)

def answer_index_consultant(system, topic, query_vector, fragments, search_index, verbose=1):

    # Поиск релевантных отрезков из базы знаний
    distances, indices =  search_index.search(query_vector, k=4)
    #indices_list = indices[0].tolist()
    # Вывод ближайших документов
    docs = [fragments[i] for i in indices[0]]
    if verbose: print('\n ===========================================: ')
    message_content = re.sub(r'\n{2}', ' ', '\n '.join([f'\nОтрывок документа №{i+1}\n=====================' + doc.page_content + '\n' for i, doc in enumerate(docs)]))
    if verbose: print('message_content :\n ======================================== \n', message_content)
    messages = [
        {"role": "system", "content": system},
        {"role": "user", "content": f"Ответь на вопрос. Документ с информацией для ответа: {message_content}\n\nВопрос пользователя: \n{topic}"}       # заполните нужными значениями, проведите эксперименты
    ]

    if verbose: print('\n ===========================================: ')

    completion =client.chat.completions.create(
        model=MODEL,                               # заполните нужным значением
        messages=messages,
        temperature=0                           # заполните нужными значениями, проведите эксперименты
    )

    #answer = insert_newlines(completion.choices[0].message.content, 50)
    return insert_newlines(completion.choices[0].message.content, 50)
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>

# %%
topic= "Что говорилось о GIT на лекции."                                      # Напишите сюда вопрос нейро-консультанту
query_vector = model.encode([topic])
query_vector = np.array(query_vector).astype('float32')

ans = answer_index_consultant(system_ru, topic, query_vector, source_chunks, db, 0)
ans
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# ' На лекции было упомянуто, что многие студенты не  знают, как настроить CI/CD на GitHub Actions,  Flare или других платформах. Это указывает на то,  что на курсе будут затрагиваться вопросы  настройки CI/CD и использования GitHub. Важно  отметить, что студенты, которые уже имеют опыт  работы с этими инструментами, могут поделиться  своими знаниями с теми, кто в этом не  разбирается, чтобы все могли научиться на  практике. Таким образом, лекция подчеркивает  значимость этих инструментов в контексте  практического применения знаний, полученных в  рамках курса.'

# %%
topic= "Что говорилось о Hadoop на лекции."                                      # Напишите сюда вопрос нейро-консультанту
query_vector = model.encode([topic])
query_vector = np.array(query_vector).astype('float32')

ans = answer_index_consultant(system_ru, topic, query_vector, source_chunks, db, 0)
ans
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# ' На лекции обсуждалась проблема эрозии  архитектурной документации на примере системы  Hadoop. В частности, было сказано, что  архитектурная документация Hadoop, как она  описана в книге "The Architecture of Open Source  Applications", выглядела определенным образом. В  документации описывались дата-моды, объединенные  в стойки, в которых хранятся блоки данных,'

# %%
topic= "Что говорилось об архитектуре приложений?"                                      # Напишите сюда вопрос нейро-консультанту
query_vector = model.encode([topic])
query_vector = np.array(query_vector).astype('float32')

ans = answer_index_consultant(system_ru, topic, query_vector, source_chunks, db, 0)
ans
# Out:
#     <style>
#     pre {
#         white-space: pre-wrap;
#     }
#     </style>
# ' В лекции обсуждалось несколько ключевых аспектов  архитектуры приложений: 1. **определение и роль  архитектуры**. Архитектура формально не  определена, но в курсе будет рассматриваться с  точки зрения производства, то есть восстановление  архитектуры по уже написанному коду. Это сложная  задача, и архитектура состоит из различных точек  зрения на систему. Также упоминается, что  архитектура не является чем-то неподвижным и  может меняться. Важно понимать, что архитектура  не является чем-то, что создается раз и навсегда.  Она может быть восстановлена по уже написанному  коду, что является важной частью работы.  Архитектура включает в себя различные точки  зрения на систему. 2. **Практические аспекты  архитектуры**. Архитектура включает в себя  различные аспекты системы, такие как командный  интерфейс, парсер, интерпретатор и т.д. Код сам  по себе также является частью архитектуры, так  как содержит всю информацию о системе, включая  объяснение, почему система устроена так, как она  есть. 3. **Бизнес-влияние архитектуры**.  Архитектура помогает сэкономить время в  разработке, позволяя использовать стандартные  библиотеки вместо разработки общих блоков с нуля.  Это особенно важно в контексте контрактов на  разработку, где точная оценка стоимости проекта  играет критическую роль. 2. **Необходимость  архитектуры в современных системах**. Архитектура  стала необходимой по мере усложнения систем. Она  позволяет управлять сложностью, организуя систему  в слои и модели, такие как OSI и TCP/IP.  Архитектура помогает решать проблемы, связанные с  масштабированием и поддержкой систем. 3.  **Компоненты системной архитектуры**. Обсуждались  статические и динамические состояния системы, а  также специфические обязанности, такие как  шифрование и визуализация. Также были рассмотрены  контекст и композиция, которые являются важными  элементами дизайна системы и обеспечивают  взаимодействие различных компонентов. 4.  **Моделирование и управление сложностью**.  Моделирование помогает изолировать ключевые  аспекты системы и определять функциональность с  помощью сценариев и кейс-использования, что  помогает контролировать сложность и обеспечивать  удобство использования системы. 5. **Влияние  требований и вызовы в поддержании архитектуры**.  Функциональные требования являются драйверами  архитектуры, и важно поддерживать актуальность  документации, чтобы избежать архитектурной  эрозии. Таким образом, архитектура приложений  рассматривалась как важный элемент, который  помогает управлять сложностью, обеспечивает  эффективное взаимодействие компонентов системы и  имеет значительное бизнес-влияние.'
